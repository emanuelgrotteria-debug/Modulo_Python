# %%
 #Esercizio: Scrivere tre algoritmi (in forma testuale) per tre task quotidiani
# Task 1: Fare la spesa al supermercato
algoritmo_spesa = """
Srivere lista alimenti da acquistare.
Prendere chiavi di casa, auto e scendere da casa.
Recarsi al supermercato.
Prendere carrello o cestino.
Mettere nel carrello gli alimenti scritti. 
Recarsi alla cassa per pagare la spesa.
Tornare a casa e sistemare la spesa.
"""

# Task 2: Studiare un concetto nuovo
algoritmo_studio = """
Scegliere l'argomento da studiare.
Prendere materiale, libri, pc.
Studiare una parte alla volta prendendo appunti.
Fare esempi pratici o esercizi per verificare la comprensione.
Ripassare periodicamente per consolidare la memoria.
"""

# Task 3: Riempire il serbatoio dell’auto
algoritmo_benzina = """
Controllare livello carburante.
Cercare il distributore più vicino.
Parcheggiare accanto alla pompa di banzina.
Scendere dall'auto e inserire la carta o i soldi nel totem.
Selezionare il n. della pompa e fare rifornimento.
Posare la pompa.
Salire in macchina.
Riaccendere il motore e andare via.
"""

# Stampa dei tre algoritmi
print(algoritmo_spesa)
print(algoritmo_studio)
print(algoritmo_benzina)
# Out:
# Srivere lista alimenti da acquistare.
# Prendere chiavi di casa, auto e scendere da casa.
# Recarsi al supermercato.
# Prendere carrello o cestino.
# Mettere nel carrello gli alimenti scritti.
# Recarsi alla cassa per pagare la spesa.
# Tornare a casa e sistemare la spesa.
#
#
# Scegliere l'argomento da studiare.
# Prendere materiale, libri, pc.
# Studiare una parte alla volta prendendo appunti.
# Fare esempi pratici o esercizi per verificare la comprensione.
# Ripassare periodicamente per consolidare la memoria.
#
#
# Controllare livello carburante.
# Cercare il distributore più vicino.
# Parcheggiare accanto alla pompa di banzina.
# Scendere dall'auto e inserire la carta o i soldi nel totem.
# Selezionare il n. della pompa e fare rifornimento.
# Posare la pompa.
# Salire in macchina.
# Riaccendere il motore e andare via.

# %%
# Esercizio 2 Abbiamo 25 studenti; memorizzare questo dato in una variabile.

Studenti = 25
print('Il numero di studenti è:',Studenti)
# Out:
# Il numero di studenti è: 25

# %%
# Aggiungo altri 3 studenti

Studenti = 25
Studenti = Studenti + 3
print('Il numero di studenti adesso è:',Studenti)
# Out:
# Il numero di studenti adesso è: 28

# %%
print('Epicode')
Epicode = 10
Epicode = Epicode + 2
Epicode = Epicode * 3
print('Il valore finale di Epicode è:',Epicode)
# Out:
# Epicode
# Il valore finale di Epicode è: 36

# %%
str1 = 'Windows'
str2 = 'Excel'
str3 = 'Powerpoint'
str4 = 'Word'
print(str1, str2, str3, str4)
print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))
# Out:
# Windows Excel Powerpoint Word
# 7
# 5
# 10
# 4

# %%
#Esercizio Calcolare e stampare a video quanti secondi ci sono in un anno non 
#bisestile.
giorni = 365
ore_al_giorno = 24
minuti_all_ora = 60
secondi_al_minuto = 60
#calcolo 
secondi_in_un_anno = giorni * ore_al_giorno * minuti_all_ora * secondi_al_minuto
print(secondi_in_un_anno)
# Out:
# 31536000

# %%
my_string = 'I am studyng Pytohn'
print(my_string.upper())
print(my_string.lower())
nuovamy_string = my_string.replace ('Pytohn','a lot')
print(nuovamy_string)

#Usando .strip non cambia nulla perchè non ci sonon spazi ne all'inizio ne alla fine del testo I am studyng Pytohn.
parole = my_string.split(' ')
print (parole)
# Out:
# I AM STUDYNG PYTOHN
# i am studyng pytohn
# I am studyng a lot
# ['I', 'am', 'studyng', 'Pytohn']

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
#Aggiungo i corsi mancanti
corsi.append('Frontend')
corsi.append('Cybersecurity')
print('studenti', studenti)
print('corsi', corsi)
# Out:
# studenti ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry']
# corsi ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
